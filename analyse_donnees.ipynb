# %%
import pandas as pd
import numpy as np

# Spécifiez le chemin du fichier de données
chemin_fichier = "alzheimer.xlsx"

# Chargez le jeu de données dans un DataFrame pandas
#df = pd.read_csv(chemin_fichier)
df=pd.pandas.read_excel(chemin_fichier ,header=0,index_col=0)

# %%
df["MMSE"]
# Out:
# Group
# Nondemented    27.0
# Nondemented    30.0
# Demented       23.0
# Demented       28.0
# Demented       22.0
#                ...
# Demented       28.0
# Demented       26.0
# Nondemented    30.0
# Nondemented    30.0
# Nondemented    30.0
# Name: MMSE, Length: 373, dtype: float64

# %%
F=df.copy()
F
# Out:
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV                  ASF
# Group
# Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696                0.883
# Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681                0.876
# Demented      M   75    12  NaN  23.0  0.5  1678  0.736                1.046
# Demented      M   76    12  NaN  28.0  0.5  1738  0.713                  NaN
# Demented      M   80    12  NaN  22.0  0.5  1698  0.701                1.034
# ...          ..  ...   ...  ...   ...  ...   ...    ...                  ...
# Demented      M   82    16  1.0  28.0  0.5  1693  0.694                1.037
# Demented      M   86    16  1.0  26.0  0.5  1688  0.675  2024-04-01 00:00:00
# Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801                1.331
# Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796                1.323
# Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801                1.317
#
# [373 rows x 9 columns]

# %%
# get the number of missing data points per column
missing_values_count = F.isnull().sum()

print("missing_values_count \n",missing_values_count)
# Out:
# missing_values_count
#  M/F      0
# Age      0
# EDUC     0
# SES     19
# MMSE     2
# CDR      0
# eTIV     0
# nWBV     0
# ASF      1
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(F.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print("percent_missing \n",percent_missing)
# Out:
# percent_missing
#  0.655347036044087

# %%
X=F.dropna()
X
# Out:
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV                  ASF
# Group
# Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696                0.883
# Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681                0.876
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710                1.444
# Nondemented   F   90    18  3.0  27.0  0.0  1200  0.718                1.462
# Nondemented   M   80    12  4.0  28.0  0.0  1689  0.712                1.039
# ...          ..  ...   ...  ...   ...  ...   ...    ...                  ...
# Demented      M   82    16  1.0  28.0  0.5  1693  0.694                1.037
# Demented      M   86    16  1.0  26.0  0.5  1688  0.675  2024-04-01 00:00:00
# Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801                1.331
# Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796                1.323
# Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801                1.317
#
# [354 rows x 9 columns]

# %%
missing_values_count = X.isnull().sum()
missing_values_count
# Out:
# M/F     0
# Age     0
# EDUC    0
# SES     0
# MMSE    0
# CDR     0
# eTIV    0
# nWBV    0
# ASF     0
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(X.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %%
#dimension
print(X.shape)
#nombre d'individus
n = X.shape[0]
#nombre de variables
p = X.shape[1]
print(n)
print(p)

#afficher les premières lignes du jeu de données
print(X.head())

#description des données
print(X.describe(include='all'))
# Out:
# (354, 9)
# 354
# 9
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Group
# Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
# Nondemented   F   90    18  3.0  27.0  0.0  1200  0.718  1.462
# Nondemented   M   80    12  4.0  28.0  0.0  1689  0.712  1.039
#         M/F         Age        EDUC         SES        MMSE         CDR  \
# count   354  354.000000  354.000000  354.000000  354.000000  354.000000
# unique    2         NaN         NaN         NaN         NaN         NaN
# top       F         NaN         NaN         NaN         NaN         NaN
# freq    204         NaN         NaN         NaN         NaN         NaN
# mean    NaN   77.033898   14.703390    2.460452   27.409605    0.271186
# std     NaN    7.811808    2.895662    1.134005    3.712626    0.370537
# ...

# %%
#dimension
#print(X.shape)
#description des données
print(X.describe(include='all'))
#df.info()
# Out:
#         M/F         Age        EDUC         SES        MMSE         CDR  \
# count   354  354.000000  354.000000  354.000000  354.000000  354.000000
# unique    2         NaN         NaN         NaN         NaN         NaN
# top       F         NaN         NaN         NaN         NaN         NaN
# freq    204         NaN         NaN         NaN         NaN         NaN
# mean    NaN   77.033898   14.703390    2.460452   27.409605    0.271186
# std     NaN    7.811808    2.895662    1.134005    3.712626    0.370537
# min     NaN   60.000000    6.000000    1.000000    4.000000    0.000000
# 25%     NaN   71.000000   12.000000    2.000000   27.000000    0.000000
# 50%     NaN   77.000000   15.000000    2.000000   29.000000    0.000000
# 75%     NaN   82.000000   16.750000    3.000000   30.000000    0.500000
# max     NaN   98.000000   23.000000    5.000000   30.000000    2.000000
#
#                eTIV        nWBV    ASF
# count    354.000000  354.000000    354
# ...

# %%
#accès à une colonne ou plusieurs
print(X.SES)
#print('_'*50)
print("\n ***************ses********************\n")
print(X.SES.mean())
print("\n ****************mean ses*******************\n")
# Out:
# Group
# Nondemented    2.0
# Nondemented    2.0
# Nondemented    3.0
# Nondemented    3.0
# Nondemented    4.0
#               ...
# Demented       1.0
# Demented       1.0
# Nondemented    2.0
# Nondemented    2.0
# Nondemented    2.0
# Name: SES, Length: 354, dtype: float64
#
#  ***************ses********************
#
# 2.4604519774011298
#
#  ****************mean ses*******************

# %%
print(X['EDUC'])
print("\n *************edic**********************\n")
print(X.MMSE.value_counts())
print("\n ****************mmse count*******************\n")
print(X['Age'].sort_values())
print("\n ******************age sorted*****************\n")
# Out:
# Group
# Nondemented    14
# Nondemented    14
# Nondemented    18
# Nondemented    18
# Nondemented    12
#                ..
# Demented       16
# Demented       16
# Nondemented    13
# Nondemented    13
# Nondemented    13
# Name: EDUC, Length: 354, dtype: int64
#
#  *************edic**********************
#
# MMSE
# 30.0    113
# 29.0     90
# 28.0     43
# 27.0     25
# 26.0     19
# 25.0     12
# 21.0     11
# 23.0      8
# 22.0      6
# 20.0      6
# 17.0      5
# 24.0      4
# 16.0      3
# 19.0      3
# 15.0      2
# 18.0      2
# 7.0       1
# 4.0       1
# Name: count, dtype: int64
#
#  ****************mmse count*******************
#
# Group
# Nondemented    60
# Nondemented    60
# Nondemented    61
# Nondemented    61
# Nondemented    61
#                ..
# Nondemented    94
# Nondemented    95
# Demented       96
# Nondemented    97
# Demented       98
# Name: Age, Length: 354, dtype: int64
#
#  ******************age sorted*****************

# %%
#5 premières lignes et colonnes
print(X.iloc[0:5,0:2])
print("\n ***********************************\n")
#lignes 2 et 3
print(X.iloc[1:3,:])
print("\n ***********************************\n")
print(X.CDR[1:2])
print("\n ***********************************\n")
#ou
print(X['CDR'][1:2])
# Out:
#             M/F  Age
# Group
# Nondemented   M   87
# Nondemented   M   88
# Nondemented   F   88
# Nondemented   F   90
# Nondemented   M   80
#
#  ***********************************
#
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Group
# Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
#
#  ***********************************
#
# Group
# Nondemented    0.0
# Name: CDR, dtype: float64
#
#  ***********************************
#
# Group
# Nondemented    0.0
# Name: CDR, dtype: float64

# %%
#Restriction avec des conditions
#print(X.loc[X['ASF']>=1,:])    
print(X.loc[(X['Age']>=70) & (X['M/F']=="F"),:])
#on peut n'afficher qu'une partie des colonnes
colonnes=['ASF','Age','MMSE']
print(X.loc[(X['ASF']>=1) & (X['Age']==70),colonnes])
# Out:
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Group
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
# Nondemented   F   90    18  3.0  27.0  0.0  1200  0.718  1.462
# Nondemented   F   93    14  2.0  30.0  0.0  1272  0.698   1.38
# Nondemented   F   95    14  2.0  29.0  0.0  1257  0.703  1.396
# Nondemented   F   78    16  2.0  29.0  0.0  1333  0.748  1.316
# ...          ..  ...   ...  ...   ...  ...   ...    ...    ...
# Nondemented   F   90    14  2.0  28.0  0.0  1495  0.746  1.174
# Nondemented   F   93    14  2.0  30.0  0.0  1488  0.735  1.179
# Nondemented   F   72    13  2.0  30.0  0.0  1510  0.723  1.162
# Demented      F   72    16  3.0  24.0  0.5  1354  0.733  1.296
# Demented      F   73    16  3.0  21.0  1.0  1351  0.708  1.299
#
# [169 rows x 9 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 6
# ...

# %%
X.ASF.dtype
X.ASF
# Out:
# Group
# Nondemented                  0.883
# Nondemented                  0.876
# Nondemented                  1.444
# Nondemented                  1.462
# Nondemented                  1.039
#                       ...
# Demented                     1.037
# Demented       2024-04-01 00:00:00
# Nondemented                  1.331
# Nondemented                  1.323
# Nondemented                  1.317
# Name: ASF, Length: 354, dtype: object

# %%
# Convertir la colonne 'ASF' en nombres flottants, en ignorant les erreurs
X['ASF'] = pd.to_numeric(X['ASF'], errors='coerce')

# Supprimer les lignes où le type de 'ASF' est différent de float
X = X.dropna(subset=['ASF'])

print(X)
# Out:
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Group
# Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
# Nondemented   F   90    18  3.0  27.0  0.0  1200  0.718  1.462
# Nondemented   M   80    12  4.0  28.0  0.0  1689  0.712  1.039
# ...          ..  ...   ...  ...   ...  ...   ...    ...    ...
# Demented      F   73    16  3.0  21.0  1.0  1351  0.708  1.299
# Demented      M   82    16  1.0  28.0  0.5  1693  0.694  1.037
# Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801  1.331
# Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796  1.323
# Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [346 rows x 9 columns]
# C:\Users\MSI\AppData\Local\Temp\ipykernel_8580\1839658368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X.ASF.dtype
# Out:
# dtype('float64')

# %%
#Restriction avec des conditions
print(X.loc[X['ASF']>=1,:]) 
#on peut n'afficher qu'une partie des colonnes
colonnes=['ASF','Age','MMSE']
print(X.loc[(X['ASF']>=1) & (X['Age']==70),colonnes])
# Out:
#             M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Group
# Nondemented   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
# Nondemented   F   90    18  3.0  27.0  0.0  1200  0.718  1.462
# Nondemented   M   80    12  4.0  28.0  0.0  1689  0.712  1.039
# Nondemented   M   83    12  4.0  29.0  0.5  1701  0.711  1.032
# Nondemented   M   85    12  4.0  30.0  0.0  1699  0.705  1.033
# ...          ..  ...   ...  ...   ...  ...   ...    ...    ...
# Demented      F   73    16  3.0  21.0  1.0  1351  0.708  1.299
# Demented      M   82    16  1.0  28.0  0.5  1693  0.694  1.037
# Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801  1.331
# Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796  1.323
# Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [314 rows x 9 columns]
#                ASF  Age  MMSE
# Group
# Nondemented  1.290   70  30.0
# Nondemented  1.166   70  30.0
# Nondemented  1.057   70  30.0
# Nondemented  1.151   70  29.0
# ...

# %%
# Sélectionner uniquement les colonnes numériques
numeric_columns = X.select_dtypes(include=['float64', 'int64'])

# Calculer la matrice de corrélation entre les colonnes numériques
correlation_matrix = numeric_columns.corr()

print(correlation_matrix)
# Out:
#            Age      EDUC       SES      MMSE       CDR      eTIV      nWBV  \
# Age   1.000000 -0.028428 -0.029778  0.057317 -0.020790  0.028970 -0.517986
# EDUC -0.028428  1.000000 -0.722100  0.175408 -0.116189  0.262189 -0.023380
# SES  -0.029778 -0.722100  1.000000 -0.141313  0.062204 -0.247971  0.080364
# MMSE  0.057317  0.175408 -0.141313  1.000000 -0.705719 -0.025977  0.342763
# CDR  -0.020790 -0.116189  0.062204 -0.705719  1.000000  0.059386 -0.352649
# eTIV  0.028970  0.262189 -0.247971 -0.025977  0.059386  1.000000 -0.199442
# nWBV -0.517986 -0.023380  0.080364  0.342763 -0.352649 -0.199442  1.000000
# ASF  -0.020646 -0.246135  0.242839  0.034114 -0.069958 -0.988838  0.203859
#
#            ASF
# Age  -0.020646
# EDUC -0.246135
# SES   0.242839
# MMSE  0.034114
# CDR  -0.069958
# eTIV -0.988838
# nWBV  0.203859
# ASF   1.000000

# %%
#scikit-learn
import sklearn
#classe StandardScaler pour standardisation (centrage et reduction)
from sklearn.preprocessing import StandardScaler
#instanciation
sc = StandardScaler()
#transformation – centrage-réduction
Z = sc.fit_transform(numeric_columns)
print(Z)
# Out:
# [[ 1.28499166 -0.23876315 -0.41956694 ...  2.84806485 -0.90808279
#   -2.29191196]
#  [ 1.41312051 -0.23876315 -0.41956694 ...  2.94486213 -1.30486252
#   -2.3431111 ]
#  [ 1.41312051  1.14386528  0.47104754 ... -1.54767029 -0.53775504
#    1.81133341]
#  ...
#  [-2.04635847 -0.58442025 -0.41956694 ... -0.95549872  1.86937534
#    0.98483301]
#  [-1.79010077 -0.58442025 -0.41956694 ... -0.90994706  1.73711543
#    0.9263197 ]
#  [-1.53384307 -0.58442025 -0.41956694 ... -0.87578332  1.86937534
#    0.88243473]]

# %%
import pandas

print(Z[0][0])
# Transformer un tableau en DataFrame
Zdf=pandas.DataFrame(Z,index=numeric_columns.index,columns=numeric_columns.columns)
print(Zdf)
print(Zdf.iloc[0,0])
# Out:
# 1.2849916578049732
#                   Age      EDUC       SES      MMSE       CDR      eTIV  \
# Group
# Nondemented  1.284992 -0.238763 -0.419567 -0.106806 -0.729462  2.848065
# Nondemented  1.413121 -0.238763 -0.419567  0.696559 -0.729462  2.944862
# Nondemented  1.413121  1.143865  0.471048  0.160982 -0.729462 -1.547670
# Nondemented  1.669378  1.143865  0.471048 -0.106806 -0.729462 -1.633080
# Nondemented  0.388090 -0.930077  1.361662  0.160982 -0.729462  1.151266
# ...               ...       ...       ...       ...       ...       ...
# Demented    -0.508812  0.452551  0.471048 -1.713534  1.969938 -0.773292
# Demented     0.644347  0.452551 -1.310181  0.160982  0.620238  1.174041
# Nondemented -2.046358 -0.584420 -0.419567  0.696559 -0.729462 -0.955499
# Nondemented -1.790101 -0.584420 -0.419567  0.696559 -0.729462 -0.909947
# Nondemented -1.533843 -0.584420 -0.419567  0.696559 -0.729462 -0.875783
#
#                  nWBV       ASF
# Group
# Nondemented -0.908083 -2.291912
# ...

# %%
#Stat - librairie numpy
import numpy
#moyenne si on garde Z en tableau
print(numpy.mean(Z,axis=0))
#écart-type si on garde Z en tableau
print(numpy.std(Z,axis=0))
# 1/n (Z'.Z) : matrice de corrélation
T=numpy.transpose(Z)
print(numpy.dot(T,Z)/n)
# Out:
# [-9.24116275e-16 -2.15627131e-16  0.00000000e+00  5.13397930e-17
#  -7.95766792e-17  4.72326096e-16 -6.77685268e-16  9.21549285e-16]
# [1. 1. 1. 1. 1. 1. 1. 1.]
# [[ 0.97740113 -0.02778581 -0.02910505  0.05602141 -0.02032011  0.02831496
#   -0.50628017 -0.02017921]
#  [-0.02778581  0.97740113 -0.70578105  0.17144425 -0.11356334  0.25626397
#   -0.02285172 -0.24057301]
#  [-0.02910505 -0.70578105  0.97740113 -0.13811984  0.06079795 -0.24236674
#    0.07854801  0.23735107]
#  [ 0.05602141  0.17144425 -0.13811984  0.97740113 -0.68977019 -0.02538997
#    0.33501735  0.03334312]
#  [-0.02032011 -0.11356334  0.06079795 -0.68977019  0.97740113  0.05804383
#   -0.34467917 -0.06837665]
#  [ 0.02831496  0.25626397 -0.24236674 -0.02538997  0.05804383  0.97740113
#   -0.19493525 -0.96649092]
#  [-0.50628017 -0.02285172  0.07854801  0.33501735 -0.34467917 -0.19493525
#    0.97740113  0.19925199]
#  [-0.02017921 -0.24057301  0.23735107  0.03334312 -0.06837665 -0.96649092
# ...

# %%
#importation de la librairie
import matplotlib.pyplot as plt
#histogramme d'une variable
X.hist(column='ASF')
# Out:
# array([[<Axes: title={'center': 'ASF'}>]], dtype=object)

# %%
#density plot
X['ASF'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
#distributions avec un boxplot
X.boxplot(column='ASF')
# Out:
# <Axes: >

# %%
#nuage de points
X.plot.scatter(x='nWBV',y='eTIV')
# Out:
# <Axes: xlabel='nWBV', ylabel='eTIV'>

# %%
#scatter_matrix
pandas.plotting.scatter_matrix(X,hist_kwds={'bins':30})
pandas.plotting.scatter_matrix(X,diagonal='kde')
# Out:
# array([[<Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='EDUC', ylabel='Age'>,
#         <Axes: xlabel='SES', ylabel='Age'>,
#         <Axes: xlabel='MMSE', ylabel='Age'>,
#         <Axes: xlabel='CDR', ylabel='Age'>,
#         <Axes: xlabel='eTIV', ylabel='Age'>,
#         <Axes: xlabel='nWBV', ylabel='Age'>,
#         <Axes: xlabel='ASF', ylabel='Age'>],
#        [<Axes: xlabel='Age', ylabel='EDUC'>,
#         <Axes: xlabel='EDUC', ylabel='EDUC'>,
#         <Axes: xlabel='SES', ylabel='EDUC'>,
#         <Axes: xlabel='MMSE', ylabel='EDUC'>,
#         <Axes: xlabel='CDR', ylabel='EDUC'>,
#         <Axes: xlabel='eTIV', ylabel='EDUC'>,
#         <Axes: xlabel='nWBV', ylabel='EDUC'>,
#         <Axes: xlabel='ASF', ylabel='EDUC'>],
#        [<Axes: xlabel='Age', ylabel='SES'>,
#         <Axes: xlabel='EDUC', ylabel='SES'>,
#         <Axes: xlabel='SES', ylabel='SES'>,
#         <Axes: xlabel='MMSE', ylabel='SES'>,
#         <Axes: xlabel='CDR', ylabel='SES'>,
# ...

# %%
#statistiques selon l'espèce
esp = X.groupby('Group')
print(esp[['MMSE']].describe())
# Out:
#               MMSE
#              count       mean       std   min   25%   50%   75%   max
# Group
# Converted     36.0  28.638889  1.570310  24.0  28.0  29.0  30.0  30.0
# Demented     123.0  24.252033  4.698436   4.0  21.0  26.0  28.0  30.0
# Nondemented  187.0  29.229947  0.883274  26.0  29.0  29.0  30.0  30.0

# %%
X.MMSE.dtypes
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# Conversion de la colonne 'ASF' en type numérique
X.loc[:, 'ASF'] = pd.to_numeric(X['ASF'], errors='coerce')

# Réinitialisation de l'index du DataFrame
X.reset_index(drop=True, inplace=True)

# Histogramme avec densité pour toute la population
plt.figure(figsize=(8, 6))
sns.histplot(data=X, x='ASF', kde=True)
plt.title("Histogramme avec densité de la variable ASF pour toute la population")
plt.xlabel("Valeur de la variable ASF")
plt.ylabel("Fréquence")
plt.show()

# Histogramme avec densité pour chaque espèce
plt.figure(figsize=(10, 8))
sns.histplot(data=X, x='ASF', hue='M/F', kde=True)
plt.title("Histogramme avec densité de la variable ASF pour chaque genre")
plt.xlabel("Valeur de la variable ASF")
plt.ylabel("Fréquence")
plt.legend(title='Genre')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Réinitialisation de l'index du DataFrame
X.reset_index(drop=True, inplace=True)

# Boxplot pour la variable ASF par espèce
plt.figure(figsize=(10, 8))
sns.boxplot(data=X, x='M/F', y='ASF', hue='M/F')
plt.title("Boxplot de la variable ASF par genre")
plt.xlabel("Genre")
plt.ylabel("Valeur de la variable ASF")
plt.legend(title='Genre')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Matrice des nuages de points pour toutes les variables
sns.pairplot(data=X)
plt.title('Matrice des nuages de points pour toutes les variables')
plt.show()

# %%
# Sélectionner uniquement les colonnes numériques
numeric_columns = X.select_dtypes(include=['float64', 'int64'])

# Calculer la matrice de corrélation
corr = numeric_columns.corr()
print(corr)
# Out:
#            Age      EDUC       SES      MMSE       CDR      eTIV      nWBV  \
# Age   1.000000 -0.028428 -0.029778  0.057317 -0.020790  0.028970 -0.517986
# EDUC -0.028428  1.000000 -0.722100  0.175408 -0.116189  0.262189 -0.023380
# SES  -0.029778 -0.722100  1.000000 -0.141313  0.062204 -0.247971  0.080364
# MMSE  0.057317  0.175408 -0.141313  1.000000 -0.705719 -0.025977  0.342763
# CDR  -0.020790 -0.116189  0.062204 -0.705719  1.000000  0.059386 -0.352649
# eTIV  0.028970  0.262189 -0.247971 -0.025977  0.059386  1.000000 -0.199442
# nWBV -0.517986 -0.023380  0.080364  0.342763 -0.352649 -0.199442  1.000000
# ASF  -0.020646 -0.246135  0.242839  0.034114 -0.069958 -0.988838  0.203859
#
#            ASF
# Age  -0.020646
# EDUC -0.246135
# SES   0.242839
# MMSE  0.034114
# CDR  -0.069958
# eTIV -0.988838
# nWBV  0.203859
# ASF   1.000000

# %%
# Calculer les valeurs et les vecteurs propres
eig_vals, eig_vecs = np.linalg.eig(corr)
print(eig_vals)
print(eig_vecs)
# Out:
# [2.44203455 2.08672159 1.33667812 1.21583318 0.01087073 0.34936797
#  0.28809321 0.27040066]
# [[ 1.06239591e-01 -1.64055596e-01  7.21530223e-01  2.82636954e-01
#    1.08520264e-02 -5.59985840e-01  2.17414456e-01 -1.83969133e-02]
#  [ 3.84704908e-01  3.02003807e-01  1.34537769e-01 -4.83765539e-01
#    1.93052440e-02  5.89507211e-02  3.19474240e-01 -6.34629542e-01]
#  [-3.91905475e-01 -2.56299087e-01 -1.88378776e-01  5.00475145e-01
#    9.75360200e-03  1.22084554e-01  2.31383080e-01 -6.52856066e-01]
#  [-2.94126255e-02  5.70039697e-01  2.01961314e-01  3.01214854e-01
#   -3.19775235e-03 -1.60015536e-02 -6.81909209e-01 -2.78216527e-01]
#  [ 7.53430992e-02 -5.55675125e-01 -1.68147351e-01 -3.38203443e-01
#   -5.19529755e-03 -4.07590400e-01 -5.33641062e-01 -3.03255279e-01]
#  [ 5.57946019e-01 -2.77931575e-02 -2.63675387e-01  3.37375466e-01
#   -7.07381993e-01 -5.80632954e-02  2.85632795e-02 -6.11085794e-04]
#  [-2.47296117e-01  4.24730940e-01 -4.62006933e-01 -4.06989306e-02
# ...

# %%
# Calcul du pourcentage de variance expliquée par chacun des axes factoriels
tot = sum(eig_vals)
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print(pd.DataFrame({'valprop':eig_vals,'inertie':var_exp,'inertiecum':cum_var_exp}))
# Out:
#     valprop    inertie  inertiecum
# 0  2.442035  30.525432   30.525432
# 1  2.086722  26.084020   56.609452
# 2  1.336678  16.708477   73.317928
# 3  1.215833  15.197915   88.515843
# 4  0.010871   4.367100   92.882943
# 5  0.349368   3.601165   96.484108
# 6  0.288093   3.380008   99.864116
# 7  0.270401   0.135884  100.000000

# %%
# Sélectionner uniquement les colonnes numériques
X_numeric = X.select_dtypes(include=np.number)

# Initialiser et ajuster le modèle ACP
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_numeric)

# Calculer les coordonnées des individus dans le nouveau repère
Tp = pca.components_.T * np.sqrt(pca.explained_variance_)

# Afficher les projections des individus sur le plan des deux premiers axes factoriels
plt.figure(figsize=(10, 8))
plt.scatter(X_pca[:, 0], X_pca[:, 1])
plt.xlabel('Premier axe factoriel')
plt.ylabel('Deuxième axe factoriel')

# Ajouter les anciens axes
for i, (comp, var) in enumerate(zip(Tp, X_numeric.columns)):
    plt.arrow(0, 0, comp[0], comp[1], color='r', alpha=0.5)
    plt.text(comp[0] * 1.15, comp[1] * 1.15, var, color='b', ha='center', va='center')

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 5
#       2 X_numeric = X.select_dtypes(include=np.number)
#       4 # Initialiser et ajuster le modèle ACP
# ----> 5 pca = PCA(n_components=2)
#       6 X_pca = pca.fit_transform(X_numeric)
#       8 # Calculer les coordonnées des individus dans le nouveau repère
#
# NameError: name 'PCA' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Agrandir le cercle
radius = 2

# Afficher le graphique avec le cercle unité
plt.figure(figsize=(10, 8))
plt.scatter(Tp[:, 0], Tp[:, 1], alpha=0.5)  # Afficher les composantes principales
plt.xlabel('Premier axe factoriel')
plt.ylabel('Deuxième axe factoriel')

# Ajouter le cercle unité avec un fond transparent
circle = plt.Circle((0, 0), radius, color='lightblue', fill=False, linewidth=2, alpha=0.5)
plt.gca().add_patch(circle)

# Ajuster l'échelle des axes
plt.xlim(-radius, radius)
plt.ylim(-radius, radius)

# Ajouter les flèches pour les variables originales
for i, (comp, var) in enumerate(zip(Tp.T, X_numeric.columns)):
    plt.arrow(0, 0, comp[0], comp[1], color='r', alpha=0.5)
    plt.text(comp[0] * 1.15, comp[1] * 1.15, var, color='r', ha='center', va='center')

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 9
#       7 # Afficher le graphique avec le cercle unité
#       8 plt.figure(figsize=(10, 8))
# ----> 9 plt.scatter(Tp[:, 0], Tp[:, 1], alpha=0.5)  # Afficher les composantes principales
#      10 plt.xlabel('Premier axe factoriel')
#      11 plt.ylabel('Deuxième axe factoriel')
#
# NameError: name 'Tp' is not defined

# %%
import matplotlib.pyplot as plt


# Définir la taille de la figure
plt.figure(figsize=(10, 8))  # Largeur = 10 pouces, Hauteur = 8 pouces

# Tracer le nuage de points individus
plt.scatter(Tp[:, 0], Tp[:, 1])

# Ajouter des labels pour les axes x et y
plt.xlabel("Axe factoriel 1")
plt.ylabel("Axe factoriel 2")

# Ajouter les anciens axes, représentés avec des flèches depuis l'origine, avec le nom des variables associées.
for i in range(len(X.columns)):
    plt.arrow(0, 0, eig_vecs[i, 0], eig_vecs[i, 1], head_width=0.4, color='r')
    plt.text(eig_vecs[i, 0], eig_vecs[i, 1], X.columns[i])

# Ajouter les noms des individus sans duplication
seen_names = set()  # Pour garder une trace des noms déjà vus

for i in range(len(X)):
    name = X.index[i]  # En supposant que le nom de l'individu est l'index du DataFrame X

    # Vérifier si le nom n'a pas déjà été vu
    if name not in seen_names:
        plt.annotate(name, (Tp[i, 0], Tp[i, 1]))
        seen_names.add(name)  # Ajouter le nom à l'ensemble pour le marquer comme vu


# Afficher le graphique
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 8
#       5 plt.figure(figsize=(10, 8))  # Largeur = 10 pouces, Hauteur = 8 pouces
#       7 # Tracer le nuage de points individus
# ----> 8 plt.scatter(Tp[:, 0], Tp[:, 1])
#      10 # Ajouter des labels pour les axes x et y
#      11 plt.xlabel("Axe factoriel 1")
#
# NameError: name 'Tp' is not defined

# %%
#k-means
from sklearn import cluster
import numpy as np

# Sélectionner uniquement les colonnes numériques
numeric_columns = X.select_dtypes(include=['float64', 'int64'])

kmeans = cluster.KMeans(n_clusters=3)
kmeans.fit(numeric_columns)

# Index triés des groupes
idk = np.argsort(kmeans.labels_)

# Affichage des observations et leurs groupes
Cldf = pd.DataFrame(numeric_columns.values[idk], index=kmeans.labels_[idk], columns=numeric_columns.columns)
print(Cldf)

# Distances aux centres de classes des observations
A = kmeans.transform(numeric_columns)
print(A)

# Création d'un DataFrame avec les classes, les ID et les distances
result_df = pd.DataFrame({'Classe': kmeans.labels_ + 1, 'ID': numeric_columns.index, 'DistG1': A[:, 0], 'DistG2': A[:, 1], 'DistG3': A[:, 2]})
print(result_df)

# ACP
from sklearn.decomposition import PCA
acp = PCA(n_components=2).fit_transform(numeric_columns)
# Out:
#      Age  EDUC  SES  MMSE  CDR    eTIV   nWBV
# 0   87.0  14.0  2.0  27.0  0.0  1987.0  0.696
# 0   81.0  11.0  4.0  28.0  0.0  1750.0  0.670
# 0   87.0  12.0  4.0  30.0  0.0  1762.0  0.718
# 0   86.0  12.0  4.0  29.0  0.0  1783.0  0.703
# 0   77.0  16.0  2.0  30.0  0.0  1628.0  0.709
# ..   ...   ...  ...   ...  ...     ...    ...
# 2   82.0  16.0  3.0  29.0  0.0  1484.0  0.760
# 2   73.0  13.0  2.0  23.0  0.5  1536.0  0.725
# 2   75.0  13.0  2.0  28.0  0.5  1520.0  0.708
# 2   75.0  12.0  3.0  28.0  0.5  1407.0  0.770
# 2   98.0  17.0  1.0  21.0  2.0  1503.0  0.660
#
# [354 rows x 7 columns]
# [[239.74697266 677.5746057  499.88894261]
#  [256.78319979 694.59162127 516.91452592]
#  [532.49675237  95.30142925 272.48125012]
#  ...
#  [428.79128645  18.30025053 168.9762473 ]
#  [420.7195102   22.20364977 160.83208182]
#  [414.65345219  26.2514866  154.69267521]]
#      Classe           ID      DistG1      DistG2      DistG3
# ...

# %%
from sklearn import cluster

kmeans = cluster.KMeans(n_clusters=4)
kmeans.fit(numeric_columns)

# Index triés des groupes
idk = np.argsort(kmeans.labels_)

# Affichage des observations et leurs groupes
print(pd.DataFrame(numeric_columns.values[idk], index=kmeans.labels_[idk], columns=numeric_columns.columns))

# Distances aux centres de classes des observations
A = kmeans.transform(numeric_columns)
result_df = pd.DataFrame({'Classe': kmeans.labels_, 'ID': numeric_columns.index, 'DistG1': A[:, 0], 'DistG2': A[:, 1], 'DistG3': A[:, 2], 'DistG4': A[:, 3]})
print(result_df)
# Out:
#      Age  EDUC  SES  MMSE  CDR    eTIV   nWBV
# 0   87.0  14.0  2.0  27.0  0.0  1987.0  0.696
# 0   85.0  12.0  3.0  30.0  0.0  1820.0  0.755
# 0   86.0  12.0  3.0  27.0  0.0  1813.0  0.761
# 0   76.0  16.0  3.0  30.0  0.0  1832.0  0.769
# 0   72.0  20.0  1.0  26.0  0.5  1911.0  0.719
# ..   ...   ...  ...   ...  ...     ...    ...
# 3   77.0  20.0  1.0  23.0  1.0  1713.0  0.756
# 3   79.0  20.0  1.0  25.0  2.0  1710.0  0.760
# 3   80.0  20.0  1.0  29.0  0.0  1587.0  0.693
# 3   92.0  16.0  1.0  30.0  0.0  1662.0  0.682
# 3   66.0  16.0  1.0  19.0  1.0  1695.0  0.711
#
# [354 rows x 7 columns]
#      Classe           ID      DistG1      DistG2      DistG3      DistG4
# 0         0  Nondemented  141.477242  514.472788  685.444569  318.832474
# 1         0  Nondemented  158.495264  531.497523  702.461719  335.867091
# 2         2  Nondemented  631.044915  257.914322   87.542181  453.335053
# 3         2  Nondemented  646.083003  272.988915  102.662623  468.369753
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calcul de l'inertie pour différents nombres de clusters
inertias = []
for i in range(1, 11):  # Tester pour un nombre de clusters de 1 à 10
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(numeric_columns.values)
    inertias.append(kmeans.inertia_)

# Tracé de la courbe du coude
plt.plot(range(1, 11), inertias, marker='o')
plt.xlabel('Nombre de clusters')
plt.ylabel("Inertie")
plt.title('Méthode du Coude pour le Choix du Nombre de Clusters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 10
#       8 for i in range(1, 11):  # Tester pour un nombre de clusters de 1 à 10
#       9     kmeans = KMeans(n_clusters=i, random_state=42)
# ---> 10     kmeans.fit(numeric_columns.values)
#      11     inertias.append(kmeans.inertia_)
#      13 # Tracé de la courbe du coude
#
# NameError: name 'numeric_columns' is not defined

# %%
# Application de l'algorithme K-means
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(numeric_columns)

# Ajout des informations de clusters aux données
numeric_columns['cluster'] = clusters

# Calcul des moyennes des caractéristiques de chaque cluster
cluster_means = numeric_columns.groupby('cluster').mean()
print("Moyennes des caractéristiques de chaque cluster :")
print(cluster_means)

# Calcul des différences significatives entre les clusters
cluster_diff = cluster_means.diff().iloc[1:]  # Différences par rapport au premier cluster
# Out:
# Moyennes des caractéristiques de chaque cluster :
#                Age       EDUC       SES       MMSE       CDR         eTIV  \
# cluster
# 0        76.666667  16.060606  2.181818  28.484848  0.196970  1843.181818
# 1        76.533333  14.466667  2.540000  27.166667  0.320000  1470.713333
# 2        76.198113  13.820755  2.811321  27.764151  0.198113  1301.641509
# 3        79.738462  16.000000  1.846154  26.846154  0.315385  1662.323077
#
#              nWBV
# cluster
# 0        0.728606
# 1        0.727793
# 2        0.744387
# 3        0.711677

# %%
print("\nDifférences significatives entre les clusters :")
print(cluster_diff)

# Caractéristiques les plus discriminantes pour chaque cluster
print("\nCaractéristiques les plus discriminantes pour chaque cluster :")
for i, row in cluster_diff.iterrows():
    print(f"Cluster {i}:")
    max_diff_feature = row.idxmax()
    max_diff_value = row.max()
    print(f"Caractéristique la plus discriminante: {max_diff_feature}, Différence: {max_diff_value}")
# Out:
# Différences significatives entre les clusters :
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 print("\nDifférences significatives entre les clusters :")
# ----> 2 print(cluster_diff)
#       4 # Caractéristiques les plus discriminantes pour chaque cluster
#       5 print("\nCaractéristiques les plus discriminantes pour chaque cluster :")
#
# NameError: name 'cluster_diff' is not defined

# %%
from sklearn.decomposition import PCA
acp = PCA(n_components = 2).fit_transform(numeric_columns)
#projeter dans le plan factoriel
#avec un code couleur différent selon le groupe
#remarquer le rôle de zip() dans la boucle
for couleur,k in zip(['red', 'blue', 'lawngreen', 'aqua'],[0,1,2,3]):
  plt.scatter(acp[kmeans.labels_==k,0], acp[kmeans.labels_==k,1],c= couleur)
plt.show()
